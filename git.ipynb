# %%
from os.path import join
from google.colab import drive

ROOT='/content/drive'
drive.mount(ROOT)
# Out:
# Mounted at /content/drive

# %%
# !pwd
# !ls /content/drive/'My Drive'/'Colab Notebooks'
# Out:
# /content
#  딥러닝실습1.ipynb	      금융파이썬쿡북.ipynb
#  딥러닝2일차.ipynb	      nh-daycon
# '딥러닝3일차(RNN).ipynb'      practical-time-series-analysis
#  cnn-chart-ananlysis	      project1.ipynb
#  deep-learning-from-scratch   python-for-finance-cookbook
#  git.ipynb		      stock-clustering
#  텍스트_분석.ipynb

# %%
PROJ = "/drive/'My Drive'/'Colab Notebooks'/"
PROJ_PATH=join(ROOT,PROJ)

# %%
import os
import sys

sys.path.insert(0, PROJ_PATH)

# %%
# %cd /content/drive/'My Drive'/'Colab Notebooks'/
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Colab Notebooks/.git/

# %%
# !git add .

# %%
# !git config --global user.email gusdud0222@naver.com
# !git config --global user.name jhy156456

# %%
# !git commit -m "first commit"
# !git branch -M main
# Out:
# [master (root-commit) 4eba5aa] first commit
#  34 files changed, 1174 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 "cnn-chart-ananlysis/CNN\341\204\216\341\205\241\341\204\220\341\205\263\341\204\207\341\205\256\341\206\253\341\204\211\341\205\245\341\206\250.ipynb"
#  create mode 100644 deep-learning-from-scratch/__pycache__/functions.cpython-37.pyc
#  create mode 100644 deep-learning-from-scratch/common/__init__.py
#  create mode 100644 deep-learning-from-scratch/common/gradient.py
#  create mode 100644 deep-learning-from-scratch/common/layers.py
#  create mode 100644 deep-learning-from-scratch/common/multi_layer_net.py
#  create mode 100644 deep-learning-from-scratch/common/multi_layer_net_extend.py
#  create mode 100644 deep-learning-from-scratch/common/optimizer.py
#  create mode 100644 deep-learning-from-scratch/common/trainer.py
#  create mode 100644 deep-learning-from-scratch/common/util.py
# ...

# %%
# !git remote add origin https://github.com/jhy156456/colab-ai.git
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git push --set-upstream origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !cd~/.ssh
# Out:
# /bin/bash: cd~/.ssh: No such file or directory

# %%
# !ssh-keygen -t rsa -b 4096 -C "devjhy1024@gmail.com"
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa.
# Your public key has been saved in /root/.ssh/id_rsa.pub.
# The key fingerprint is:
# SHA256:J678iV8+msYKyktbpVYMTol7FuIuny+ZP8JM8XIfuWM devjhy1024@gmail.com
# The key's randomart image is:
# +---[RSA 4096]----+
# |                 |
# |   . .           |
# |  o =            |
# | ..= +           |
# |  oo+ +.S .      |
# | .ooo+o. o       |
# |.+o==. +. .      |
# | =B*.oEoo=.      |
# |  B*oo=**...     |
# +----[SHA256]-----+

# %%
# !eva$ eval "$(ssh-agent -s)"
# Out:
# /bin/bash: eva$: command not found

# %%
cd~/.ssh

# %%
# !ssh-add~/.ssh/id_rsa
# Out:
# /bin/bash: ssh-add~/.ssh/id_rsa: No such file or directory

# %%
eva$ eval "$(ssh-agent -s)"
# Out:
#   File "<ipython-input-35-9acbb264307b>", line 1
#     eva$ eval "$(ssh-agent -s)"
#        ^
# SyntaxError: invalid syntax

# %%
cat id_rsa.pub
# Out:
# ssh-rsa ... devjhy1024@gmail.com

# %%
# !cd~/.ssh
# Out:
# /bin/bash: cd~/.ssh: No such file or directory

# %%
# !ls
# Out:
#  딥러닝실습1.ipynb	      금융파이썬쿡북.ipynb
#  딥러닝2일차.ipynb	      nh-daycon
# '딥러닝3일차(RNN).ipynb'      practical-time-series-analysis
#  cnn-chart-ananlysis	      project1.ipynb
#  deep-learning-from-scratch   python-for-finance-cookbook
#  git.ipynb		      stock-clustering
#  텍스트_분석.ipynb
